# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import re
import json

# %%
url = "https://www.e-vuc.sk/zsk/zdravotnictvo/ambulantna-pohotovostna-sluzba-v-zsk.html?page_id=127105"
page = requests.get(url)
soup = BeautifulSoup(page.content, "html.parser")
data = []
table = soup.find('table', attrs={'class':'list'})
rows = table.find_all('tr')
for row in rows:
    okres_link = row.find("a")['href']
    okres_nazov =  row.find("a").text.strip()
    page = requests.get(okres_link)
    soup = BeautifulSoup(page.content, "html.parser")
    table = soup.find('table', attrs={'class':'list'})
    rowsOkres = table.find_all('tr')
    for rows2 in rowsOkres:
        title_html = rows2.find('a')
        specialization = rows2.find('span').text.replace("(", " ").replace(")", "")
            
        title = title_html.text.strip()

        doctor_url = ""
        if title_html.has_attr('href'):
            doctor_url = title_html['href']
        

    


        data_row = {
            "title" : title,
            "doctor_url" : doctor_url,
            "doctor_id" : specialization,
            "kraj_id" : "7",
            "okres" : okres_nazov.split(" ")[1],

        }
        data.append(data_row)
aps = pd.DataFrame(data)

# %%
aps
# Out:
#                                                 title  \
# 0   Ambulantná pohotovostná služba pre dospelých, ...
# 1   Ambulantná pohotovostná služba pre dospelých, ...
# 2   Ambulantná pohotovostná služba pre deti a dora...
# 3   Zubno–lekárska pohotovostná služba, Palárikova...
# 4   Ambulantná pohotovostná služba pre dospelých, ...
# 5   Ambulantná pohotovostná služba pre deti a dora...
# 6   Ambulantná pohotovostná služba pre dospelých, ...
# 7   Ambulantná pohotovostná služba pre deti a dora...
# 8   Ambulantná pohotovostná služba pre dospelých, ...
# 9   Ambulantná pohotovostná služba pre deti a dora...
# 10  Ambulantná pohotovostná služba pre dospelých, ...
# 11  Ambulantná pohotovostná služba pre deti a dora...
# 12  Zubno–lekárska pohotovostná služba, Školská, L...
# 13  Ambulantná pohotovostná služba pre deti a dora...
# 14  Zubno–lekárska pohotovostná služba, Škultétyho...
# 15  Ambulantná pohotovostná služba pre deti a dora...
# 16  Ambulantná pohotovostná služba pre dospelých, ...
# 17  Ambulantná pohotovostná služba pre dospelých, ...
# 18  Ambulantná pohotovostná služba pre deti a dora...
# 19  Zubno–lekárska pohotovostná služba, Červeného ...
# 20  Ambulantná pohotovostná služba pre dospelých, ...
# 21  Ambulantná pohotovostná služba pre deti a dora...
# 22  Zubno–lekárska pohotovostná služba, Gen. Miloš...
# 23  Ambulantná pohotovostná služba pre dospelých, ...
# 24  Ambulantná pohotovostná služba pre deti a dora...
# 25  Ambulantná pohotovostná služba pre deti a dora...
# 26  Ambulantná pohotovostná služba pre dospelých, ...
# 27  Ambulantná pohotovostná služba pre deti a dora...
# 28  Zubno–lekárska pohotovostná služba, Mieru, Trs...
# 29  Zubno–lekárska pohotovostná služba, Jána Milca...
# 30  Ambulantná pohotovostná služba pre dospelých, ...
# 31  Ambulantná pohotovostná služba pre deti a dora...
#
#                                            doctor_url          doctor_id  \
# 0    https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-37983181-A0001
# 1    https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-48027782-A0001
# 2    https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-17335825-A0002
# 3    https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  65-17335469-A0052
# 4    https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-17335469-A0002
# 5    https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-17335469-A0003
# 6    https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-00634905-A0003
# 7    https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-00634905-A0002
# 8    https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-36691291-A0001
# 9    https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-17335825-A0002
# 10   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-17336163-A0003
# 11   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-17336163-A0002
# 12   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  65-47492678-A0001
# 13   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-47553804-A0001
# 14   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  65-51257076-A0002
# 15   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-00365327-A0002
# 16   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-36402753-A0001
# 17   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-00634875-A0002
# 18   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-00634875-A0001
# 19   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  65-00634875-A0016
# 20   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-31936415-A0243
# 21   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-36752797-A0001
# 22   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-31936415-A0076
# 23   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-50146009-A0005
# 24   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-47553804-A0001
# 25   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-00365327-A0002
# 26   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-00634891-A0002
# 27   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-00634891-A0001
# 28   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  65-00634891-A0045
# 29   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-52312615-A0004
# 30   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-17335825-A0001
# 31   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...  51-17335825-A0002
#
#    kraj_id       okres
# 0        7       Bytča
# 1        7       Bytča
# 2        7       Bytča
# 3        7       Čadca
# 4        7       Čadca
# 5        7       Čadca
# 6        7       Dolný
# 7        7       Dolný
# 8        7     Kysucké
# 9        7     Kysucké
# 10       7   Liptovský
# 11       7   Liptovský
# 12       7   Liptovský
# 13       7      Martin
# 14       7      Martin
# 15       7      Martin
# 16       7      Martin
# 17       7   Námestovo
# 18       7   Námestovo
# 19       7   Námestovo
# 20       7  Ružomberok
# 21       7  Ružomberok
# 22       7  Ružomberok
# 23       7  Turčianske
# 24       7  Turčianske
# 25       7  Turčianske
# 26       7    Tvrdošín
# 27       7    Tvrdošín
# 28       7    Tvrdošín
# 29       7      Žilina
# 30       7      Žilina
# 31       7      Žilina

# %%
lekaren_info = []
for index, lekaren in aps.iterrows():
    url = lekaren['doctor_url']
    page = requests.get(url)
    soup = BeautifulSoup(page.content, "html.parser")
    table = soup.find('table', attrs={'class': 'data_table'})
    regex = "[^\w ]"
    rows = table.find_all('tr')

    info_dict = {}
    doctor_id = ""

    for row in rows:
        if row.find('th') != None:
            try:
                th = row.find('th').text.strip()
                th = re.sub(regex, "", th, count=0, flags=0).strip()

                td = row.find('td').text
                td_rows = []
                for td_row in td.split("\n"):
                    r = td_row.strip()
                    if r != "":
                        td_rows.append(r)

                info_dict[th] = "\n".join(td_rows)
                if th == "Identifikátor":
                    doctor_id = td_rows[0]
            except:
                pass

    tables_hours = soup.find_all(
        'table', attrs={"class": 'data_table no-full-width'})
    table_hours_text = []
    for hour_table in tables_hours:
        for tr in hour_table.find_all('tr'):
            if tr.find('th') != None:
                th = tr.find('th').text.strip()
            if tr.find('td') != None:
                td = tr.find('td').text.strip()
            table_hours_text.append(re.sub(r"\s ", "", th) + " " + re.sub(r"\s ", "", td))

    table_hours_text = "\n".join(table_hours_text)



    table_services = soup.find_all('table', attrs={"class": 'data_table no-margin'})

    services_text = ""
    if len(table_services) >= 1:
        table_services = table_services[0].find('tr')

        text1 = table_services.find_all("td")[0].text.strip()
        text2 = table_services.find_all("td")[1].text.strip()
        services_text = f"DNES {text1} {text2}"

    next_services = soup.find_all('div', attrs={"class":'row every-nth-greyed'})

    for s in next_services:
        text = s.text.strip().replace("\n\r\n", "\n").replace("\n\n","\n")
        text = re.sub(' +', ' ', text)
        services_text += "\n" + text.replace("\n", " ")

    map = soup.find('a', attrs={'title': 'Mapa'})

    lat, lng = map['href'].split(":")[2].split(",")[0], map['href'].split(":")[2].split(",")[1]
    df_row = {
        "doctor_id" : doctor_id,
        "info" :  info_dict,
        "open_hours" : table_hours_text,
        "lat" : lat,
        "lng" : lng,
        "services" : services_text
    }
    lekaren_info.append(df_row)

# %%
# Opening JSON file
f = open('data/okres_ids.json')
  
# returns JSON object as 
# a dictionary
j = json.load(f)
j_dic = { x['name'] : x['id'] for x in j }
j_dic['Dolný'] = 12
j_dic['Kysucké'] = 27
j_dic['Liptovský'] = 30
j_dic['Turčianske'] = 68

lekaren_info_df = pd.DataFrame(lekaren_info)
lekaren_info_df['adresa'] = lekaren_info_df['info'].apply(lambda row :  row['Miesto prevádzkovania'])
lekaren_df = lekaren_info_df.join(aps.drop(columns=["doctor_id"]))
lekaren_df['okres_id'] = lekaren_df['okres'].apply(lambda x : j_dic[x])

# %%
lekaren_df
# Out:
#             doctor_id                                               info  \
# 2   51-17335825-A0002  {'Druh zariadenia': 'ambulancia pevnej APS pre...
# 5   51-17335469-A0003  {'Druh zariadenia': 'ambulancia pevnej APS pre...
# 7   51-00634905-A0002  {'Druh zariadenia': 'ambulancia pevnej APS pre...
# 9   51-17335825-A0002  {'Druh zariadenia': 'ambulancia pevnej APS pre...
# 11  51-17336163-A0002  {'Druh zariadenia': 'ambulancia pevnej APS pre...
# 13  51-47553804-A0001  {'Druh zariadenia': 'ambulancia pevnej APS pre...
# 15  51-00365327-A0002  {'Druh zariadenia': 'ambulancia pevnej APS pre...
# 18  51-00634875-A0001  {'Druh zariadenia': 'ambulancia pevnej APS pre...
# 21  51-36752797-A0001  {'Druh zariadenia': 'ambulancia pevnej APS pre...
# 24  51-47553804-A0001  {'Druh zariadenia': 'ambulancia pevnej APS pre...
# 25  51-00365327-A0002  {'Druh zariadenia': 'ambulancia pevnej APS pre...
# 27  51-00634891-A0001  {'Druh zariadenia': 'ambulancia pevnej APS pre...
# 31  51-17335825-A0002  {'Druh zariadenia': 'ambulancia pevnej APS pre...
#
#                                            open_hours         lat         lng  \
# 2   Telefón platnosť od: 01.07.2018\nPondelok: 16:...  49.2187404  18.7457299
# 5   Poskytovateľ platnosť od: 01.07.2018\nPondelok...  49.4389582  18.7710052
# 7   Poskytovateľ platnosť od: 01.01.2020\nPondelok...  49.2142137  19.3030945
# 9   Telefón platnosť od: 01.07.2018\nPondelok: 16:...  49.2187404  18.7457299
# 11  Poskytovateľ platnosť od: 01.07.2018\nPondelok...  49.0847466  19.5979604
# 13  Poskytovateľ platnosť od: 27.09.2018\nPondelok...  49.0657258  18.9200501
# 15  Poskytovateľ platnosť od: 01.07.2018\nPondelok...  49.0604008  18.9194998
# 18  Telefón platnosť od: 01.07.2018\nPondelok: 16:...  49.4058244  19.4760923
# 21  Telefón platnosť od: 01.07.2018\nTelefón Ambul...  49.0814735  19.3068768
# 24  Poskytovateľ platnosť od: 27.09.2018\nPondelok...  49.0657258  18.9200501
# 25  Poskytovateľ platnosť od: 01.07.2018\nPondelok...  49.0604008  18.9194998
# 27  Poskytovateľ platnosť od: 01.07.2018\nPondelok...  49.3580167  19.6014858
# 31  Telefón platnosť od: 01.07.2018\nPondelok: 16:...  49.2187404  18.7457299
#
#                                              services  \
# 2   DNES 07:00 - 14:30 Fakultná nemocnica s polikl...
# 5   DNES 07:00 - 22:00 Kysucká nemocnica s polikli...
# 7   DNES 07:00 - 22:00 Dolnooravská nemocnica s po...
# 9   DNES 07:00 - 14:30 Fakultná nemocnica s polikl...
# 11  DNES 07:00 - 22:00 Liptovská nemocnica s polik...
# 13  DNES 07:00 - 22:00 MUDr. Vanda Pedanová, s.r.o...
# 15
# 18  DNES 07:00 - 22:00 Oravská poliklinika Námesto...
# 21  DNES 07:00 - 22:00 Nosko Health Prevention, s....
# 24  DNES 07:00 - 22:00 MUDr. Vanda Pedanová, s.r.o...
# 25
# 27  DNES 07:00 - 22:00 Hornooravská nemocnica s po...
# 31  DNES 07:00 - 14:30 Fakultná nemocnica s polikl...
#
#                                                adresa  \
# 2   FNsP Žilina\nVojtecha Spanyola\n43\n01207\nŽilina
# 5   Kysucká nemocnica s poliklinikou Čadca\nPalári...
# 7   Dolnooravská nemocnica s poliklinikou MUDr. L....
# 9   FNsP Žilina\nVojtecha Spanyola\n43\n01207\nŽilina
# 11  Liptovská nemocnica s poliklinikou MUDr. Ivana...
# 13                  P. Mudroňa\n495/27\n03601\nMartin
# 15  Univerzitná nemocnica Martin\nKollárova\n2\n03...
# 18  1. poschodí - B trakt, č. dverí 172\nČerveného...
# 21      1. poschodie\nHurbanova\n5\n03401\nRužomberok
# 24                  P. Mudroňa\n495/27\n03601\nMartin
# 25  Univerzitná nemocnica Martin\nKollárova\n2\n03...
# 27  Hornooravská nemocnica s poliklinikou Trstená\...
# 31  FNsP Žilina\nVojtecha Spanyola\n43\n01207\nŽilina
#
#                                                 title  \
# 2   Ambulantná pohotovostná služba pre deti a dora...
# 5   Ambulantná pohotovostná služba pre deti a dora...
# 7   Ambulantná pohotovostná služba pre deti a dora...
# 9   Ambulantná pohotovostná služba pre deti a dora...
# 11  Ambulantná pohotovostná služba pre deti a dora...
# 13  Ambulantná pohotovostná služba pre deti a dora...
# 15  Ambulantná pohotovostná služba pre deti a dora...
# 18  Ambulantná pohotovostná služba pre deti a dora...
# 21  Ambulantná pohotovostná služba pre deti a dora...
# 24  Ambulantná pohotovostná služba pre deti a dora...
# 25  Ambulantná pohotovostná služba pre deti a dora...
# 27  Ambulantná pohotovostná služba pre deti a dora...
# 31  Ambulantná pohotovostná služba pre deti a dora...
#
#                                            doctor_url kraj_id       okres  \
# 2    https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...       7       Bytča
# 5    https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...       7       Čadca
# 7    https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...       7       Dolný
# 9    https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...       7     Kysucké
# 11   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...       7   Liptovský
# 13   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...       7      Martin
# 15   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...       7      Martin
# 18   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...       7   Námestovo
# 21   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...       7  Ružomberok
# 24   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...       7  Turčianske
# 25   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...       7  Turčianske
# 27   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...       7    Tvrdošín
# 31   https://www.e-vuc.sk/zsk/zdravotnictvo/ambula...       7      Žilina
#
#     okres_id  isDetska
# 2          9         1
# 5         74         1
# 7         12         1
# 9         27         1
# 11        30         1
# 13        33         1
# 15        33         1
# 18        40         1
# 21        53         1
# 24        68         1
# 25        68         1
# 27        69         1
# 31        78         1

# %%
lekaren_df['isDetska'] = lekaren_df['info'].apply(lambda x :  1 if "ambulancia pevnej APS pre deti a dorast" in x['Druh zariadenia'] else 0 )

# %%
lekaren_df = lekaren_df[lekaren_df['isDetska'] == 1]
lekaren_df.to_excel("zilina_aps.xlsx", index=False,encoding='utf-8')
# Out:
# /Users/williambrach/Developer/hack-health/evuc-scraper/evuc/lib/python3.8/site-packages/pandas/util/_decorators.py:211: FutureWarning: the 'encoding' keyword is deprecated and will be removed in a future version. Please take steps to stop the use of 'encoding'
#   return func(*args, **kwargs)
